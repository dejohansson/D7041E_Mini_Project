# %%
import os
import numpy as np
from python_speech_features import mfcc
from python_speech_features import delta
from python_speech_features import logfbank
import scipy.io.wavfile as wav

# %%
def f_relu(X, deriv=False):
    return np.maximum(X, 0)

def f_sigmoid(X, deriv=False):
    if not deriv:
        return 1 / (1 + np.exp(-X))
    else:
        return f_sigmoid(X)*(1 - f_sigmoid(X))


def f_softmax(X):
    Z = np.sum(np.exp(X), axis=1)
    Z = Z.reshape(Z.shape[0], 1)
    return np.exp(X) / Z

# %%
#Functionality of a single hidden layer
class Layer:
    def __init__(self, size, batch_size, is_input=False, is_output=False,
                 activation=f_sigmoid):
        self.is_input = is_input
        self.is_output = is_output

        # Z is the matrix that holds output values
        self.Z = np.zeros((batch_size, size[0]))
        # The activation function is an externally defined function (with a
        # derivative) that is stored here
        self.activation = activation

        # W is the outgoing weight matrix for this layer
        self.W = None
        # S is the matrix that holds the inputs to this layer
        self.S = None
        # D is the matrix that holds the deltas for this layer
        self.D = None
        # Fp is the matrix that holds the derivatives of the activation function
        self.Fp = None

        if not is_input:
            self.S = np.zeros((batch_size, size[0]))
            self.D = np.zeros((batch_size, size[0]))

        if not is_output:
            self.W = np.random.normal(size=size, scale=1E-4)

        if not is_input and not is_output:
            self.Fp = np.zeros((size[0], batch_size))

    def forward_propagate(self):
        if self.is_input:
            return self.Z.dot(self.W)

        self.Z = self.activation(self.S)
        if self.is_output:
            return self.Z
        else:
            # For hidden layers, we add the bias values here
            self.Z = np.append(self.Z, np.ones((self.Z.shape[0], 1)), axis=1)
            self.Fp = self.activation(self.S, deriv=True).T
            return self.Z.dot(self.W)

# %%
class MultiLayerPerceptron:
    def __init__(self, layer_config, batch_size=100, eta=0.05, nepochs=70):
        self.layers = []
        self.num_layers = len(layer_config)
        self.minibatch_size = batch_size

        for i in range(self.num_layers-1):
            if i == 0:
                print ("Initializing input layer with size {0}.".format(layer_config[i]))
                # Here, we add an additional unit at the input for the bias
                # weight.
                self.layers.append(Layer([layer_config[i]+1, layer_config[i+1]],
                                         batch_size,
                                         is_input=True))
            else:
                print ("Initializing hidden layer with size {0}.".format(layer_config[i]))
                # Here we add an additional unit in the hidden layers for the
                # bias weight.
                self.layers.append(Layer([layer_config[i]+1, layer_config[i+1]],
                                         batch_size,
                                         activation=f_sigmoid))

        print ("Initializing output layer with size {0}.".format(layer_config[-1]))
        self.layers.append(Layer([layer_config[-1], None],
                                 batch_size,
                                 is_output=True,
                                 activation=f_softmax))
        print ("Done!")

    def forward_propagate(self, data):
        # We need to be sure to add bias values to the input
        self.layers[0].Z = np.append(data, np.ones((data.shape[0], 1)), axis=1)

        for i in range(self.num_layers-1):
            self.layers[i+1].S = self.layers[i].forward_propagate()
        return self.layers[-1].forward_propagate()

    def backpropagate(self, yhat, labels):

        self.layers[-1].D = (yhat - labels).T
        for i in range(self.num_layers-2, 0, -1):
            W_nobias = self.layers[i].W[0:-1, :]
            
            self.layers[i].D = W_nobias.dot(self.layers[i+1].D) * self.layers[i].Fp

    def update_weights(self, eta):
        for i in range(0, self.num_layers-1):
            W_grad = -eta*(self.layers[i+1].D.dot(self.layers[i].Z)).T
            self.layers[i].W += W_grad

    def evaluate(self, train_data, train_labels, test_data, test_labels,
                 num_epochs, eta, eval_train=False, eval_test=True):

        N_train = len(train_labels)*len(train_labels[0])
        N_test = len(test_labels)*len(test_labels[0])

        print ("Training for {0} epochs...".format(num_epochs))
        for t in range(0, num_epochs):
            out_str = "[{0:4d}] ".format(t)

            for b_data, b_labels in zip(train_data, train_labels):
                output = self.forward_propagate(b_data)
                self.backpropagate(output, b_labels)
                self.update_weights(eta=eta)

            if eval_train:
                errs = 0
                for b_data, b_labels in zip(train_data, train_labels):
                    output = self.forward_propagate(b_data)
                    yhat = np.argmax(output, axis=1)
                    errs += np.sum(1-b_labels[np.arange(len(b_labels)), yhat])

                out_str = ("{0} Training error: {1:.5f}".format(out_str,
                                                           float(errs)/N_train))

            if eval_test:
                errs = 0
                for b_data, b_labels in zip(test_data, test_labels):
                    output = self.forward_propagate(b_data)
                    yhat = np.argmax(output, axis=1)
                    errs += np.sum(1-b_labels[np.arange(len(b_labels)), yhat])

                out_str = ("{0} Test error: {1:.5f}").format(out_str,
                                                       float(errs)/N_test)

            print (out_str)

# %%
def label_to_bit_vector(labels, nbits):
    bit_vector = np.zeros((labels.shape[0], nbits))
    for i in range(labels.shape[0]):
        bit_vector[i, labels[i]] = 1.0

    return bit_vector

# %%
def create_batches(data, labels, batch_size, create_bit_vector=False):
    N = data.shape[0]
    print ("Batch size {0}, the number of examples {1}.".format(batch_size,N))

    if N % batch_size != 0:
        print ("Warning in create_minibatches(): Batch size {0} does not " \
              "evenly divide the number of examples {1}.".format(batch_size,N))
    chunked_data = []
    chunked_labels = []
    idx = 0
    while idx + batch_size <= N:
        chunked_data.append(data[idx:idx+batch_size, :])
        if not create_bit_vector:
            chunked_labels.append(labels[idx:idx+batch_size])
        else:
            bit_vector = label_to_bit_vector(labels[idx:idx+batch_size], 3) #I change this
            chunked_labels.append(bit_vector)

        idx += batch_size

    return chunked_data, chunked_labels

# %%
def prepare_for_backprop(batch_size, Train_images, Train_labels, Valid_images, Valid_labels):
    
    print ("Creating data...")
    batched_train_data, batched_train_labels = create_batches(Train_images, Train_labels,
                                              batch_size,
                                              create_bit_vector=True)
    batched_valid_data, batched_valid_labels = create_batches(Valid_images, Valid_labels,
                                              batch_size,
                                              create_bit_vector=True)
    print ("Done!")


    return batched_train_data, batched_train_labels,  batched_valid_data, batched_valid_labels

# %%
frenchData = []
englishData = []
minLength = np.Infinity

print("Loading french...")
for folder in os.listdir("dataset/french"):
    try:
        for file in os.listdir(os.path.join("dataset/french", folder, "wav")):
            (rate,sig) = wav.read(os.path.join("dataset/french", folder, "wav", file))
            frenchData.append((sig, rate))
            if sig.size < minLength:
                minLength = sig.size
    except FileNotFoundError:
        pass
    
frenchData = np.array(frenchData)
print("Done!")

index = 1

print("Loading english...")
for folder in os.listdir("dataset/english"):
    if index > frenchData.shape[0]:
        break;
    try:
        for file in os.listdir(os.path.join("dataset/english", folder, "wav")):
            if index > frenchData.shape[0]:
                break;
            (rate,sig) = wav.read(os.path.join("dataset/english", folder, "wav", file))
            englishData.append((sig, rate))
            index += 1
            if sig.size < minLength:
                minLength = sig.size
    except FileNotFoundError:
        pass
    
englishData = np.array(englishData)
print("Done!")
# Out:
# Loading french...
# Done!
# Loading english...
# Done!

# %%
frenchMFCC = []
englishMFCC = []

#d_mfcc_feat = delta(mfcc_feat, 2)
#fbank_feat = logfbank(sig,rate)

print("Processing french...")
for i in range(frenchData.shape[0]):
    frenchMFCC.append(mfcc(frenchData[i][0][:minLength], frenchData[i][1]))
frenchMFCC = np.array(frenchMFCC)
print("Done!")

print("Processing english...")
for i in range(englishData.shape[0]):
    englishMFCC.append(mfcc(englishData[i][0][:minLength], englishData[i][1]))
englishMFCC = np.array(englishMFCC)
print("Done!")
# Out:
# Processing french...
# Done!
# Processing english...
# Done!

# %%
Xtr = np.concatenate([frenchMFCC[:4000], englishMFCC[:5000]])
Ltr = np.concatenate([np.zeros(4000), np.ones(4000), np.ones(1000)*2]).astype("int")
X_test = np.concatenate([frenchMFCC[10000:11000], englishMFCC[10000:11000]])
L_test = np.concatenate([np.zeros(1000), np.ones(500), np.ones(500)*2]).astype("int")

#L_test = np.concatenate([L_test, np.ones(500)*2])

Xtr = Xtr.reshape(Xtr.shape[0], Xtr.shape[1]*Xtr.shape[2]).astype("float32")
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1]*X_test.shape[2]).astype("float32")

Xtr = (Xtr-Xtr.min()) / (Xtr.max()-Xtr.min())      #Xtr / np.maximum(np.abs(Xtr.max()), np.abs(Xtr.min()))
X_test = X_test = (X_test-X_test.min()) / (X_test.max()-X_test.min())   #X_test / np.maximum(np.abs(X_test.max()), np.abs(X_test.min()))

# %%
#from keras.datasets import mnist
#(Xtr, Ltr), (X_test, L_test)=mnist.load_data()

#Xtr = Xtr.reshape(60000, 784)
#X_test = X_test.reshape(10000, 784)
#Xtr = Xtr.astype('float32')
#X_test = X_test.astype('float32')
#Xtr /= 255
#X_test /= 255
#print(Xtr.shape[0], 'train samples')
#print(X_test.shape[0], 'test samples')

# %%
batch_size=100;

train_data, train_labels, valid_data, valid_labels=prepare_for_backprop(batch_size, Xtr, Ltr, X_test, L_test)

mlp = MultiLayerPerceptron(layer_config=[Xtr.shape[1], 100, 100, 3], batch_size=batch_size, eta=0.005, nepochs=70)

mlp.evaluate(train_data, train_labels, valid_data, valid_labels,
             eval_train=True,eta=0.005, num_epochs=70)

print("Done:)\n")
# Out:
# Creating data...
# Batch size 100, the number of examples 9000.
# Batch size 100, the number of examples 2000.
# Done!
# Initializing input layer with size 897.
# Initializing hidden layer with size 100.
# Initializing hidden layer with size 100.
# Initializing output layer with size 3.
# Done!
# Training for 70 epochs...
# [   0]  Training error: 0.88889 Test error: 0.75000
# [   1]  Training error: 0.88889 Test error: 0.75000
# [   2]  Training error: 0.88889 Test error: 0.75000
# [   3]  Training error: 0.88889 Test error: 0.75000
# [   4]  Training error: 0.88889 Test error: 0.75000
# [   5]  Training error: 0.88889 Test error: 0.75000
# [   6]  Training error: 0.88889 Test error: 0.75000
# [   7]  Training error: 0.88889 Test error: 0.75000
# [   8]  Training error: 0.88889 Test error: 0.75000
# [   9]  Training error: 0.88889 Test error: 0.75000
# [  10]  Training error: 0.88889 Test error: 0.75000
# [  11]  Training error: 0.88889 Test error: 0.75000
# [  12]  Training error: 0.88889 Test error: 0.75000
# [  13]  Training error: 0.88889 Test error: 0.75000
# [  14]  Training error: 0.88889 Test error: 0.75000
# [  15]  Training error: 0.88889 Test error: 0.75000
# [  16]  Training error: 0.88889 Test error: 0.75000
# [  17]  Training error: 0.88889 Test error: 0.75000
# [  18]  Training error: 0.88889 Test error: 0.75000
# [  19]  Training error: 0.88889 Test error: 0.75000
# [  20]  Training error: 0.88889 Test error: 0.75000
# [  21]  Training error: 0.88889 Test error: 0.75000
# [  22]  Training error: 0.88889 Test error: 0.75000
# [  23]  Training error: 0.88889 Test error: 0.75000
# [  24]  Training error: 0.88889 Test error: 0.75000
# [  25]  Training error: 0.88889 Test error: 0.75000
# [  26]  Training error: 0.88889 Test error: 0.75000
# [  27]  Training error: 0.88889 Test error: 0.75000
# [  28]  Training error: 0.88889 Test error: 0.75000
# [  29]  Training error: 0.88889 Test error: 0.75000
# [  30]  Training error: 0.88889 Test error: 0.75000
# [  31]  Training error: 0.88889 Test error: 0.75000
# [  32]  Training error: 0.88889 Test error: 0.75000
# [  33]  Training error: 0.88889 Test error: 0.75000
# [  34]  Training error: 0.88889 Test error: 0.75000
# [  35]  Training error: 0.88889 Test error: 0.75000
# [  36]  Training error: 0.88889 Test error: 0.75000
# [  37]  Training error: 0.88889 Test error: 0.75000
# [  38]  Training error: 0.88889 Test error: 0.75000
# [  39]  Training error: 0.88889 Test error: 0.75000
# [  40]  Training error: 0.88889 Test error: 0.75000
# [  41]  Training error: 0.88889 Test error: 0.75000
# [  42]  Training error: 0.88889 Test error: 0.75000
# [  43]  Training error: 0.88889 Test error: 0.75000
# [  44]  Training error: 0.88889 Test error: 0.75000
# [  45]  Training error: 0.88889 Test error: 0.75000
# [  46]  Training error: 0.88889 Test error: 0.75000
# [  47]  Training error: 0.88889 Test error: 0.75000
# [  48]  Training error: 0.88889 Test error: 0.75000
# [  49]  Training error: 0.88889 Test error: 0.75000
# [  50]  Training error: 0.88889 Test error: 0.75000
# [  51]  Training error: 0.88889 Test error: 0.75000
# [  52]  Training error: 0.88889 Test error: 0.75000
# [  53]  Training error: 0.88889 Test error: 0.75000
# [  54]  Training error: 0.88889 Test error: 0.75000
# [  55]  Training error: 0.88889 Test error: 0.75000
# [  56]  Training error: 0.88889 Test error: 0.75000
# [  57]  Training error: 0.88889 Test error: 0.75000
# [  58]  Training error: 0.88889 Test error: 0.75000
# [  59]  Training error: 0.88889 Test error: 0.75000
# [  60]  Training error: 0.88889 Test error: 0.75000
# [  61]  Training error: 0.88889 Test error: 0.75000
# [  62]  Training error: 0.88889 Test error: 0.75000
# [  63]  Training error: 0.88889 Test error: 0.75000
# [  64]  Training error: 0.88889 Test error: 0.75000
# [  65]  Training error: 0.88889 Test error: 0.75000
# [  66]  Training error: 0.88889 Test error: 0.75000
# [  67]  Training error: 0.88889 Test error: 0.75000
# [  68]  Training error: 0.88889 Test error: 0.75000
# [  69]  Training error: 0.88889 Test error: 0.75000
# Done:)

# %%
#Xtr = Xtr/Xtr.max()    #max(abs(max), abs(min))

print(Xtr.max())
print(Xtr.min())
print(X_test.max())
print(X_test.min())

# %%
(np.ones(5)*2).astype("int")
# Out:
# array([2, 2, 2, 2, 2])
